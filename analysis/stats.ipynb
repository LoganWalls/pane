# %%
import graphlab as gl

nyt = gl.SFrame('nyt.sf')
aca = gl.SFrame('academic_articles.sf')
# Out:
# /home/loganwls/.local/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:315: SNIMissingWarning: An HTTPS request has been made, but the SNI (Subject Name Indication) extension to TLS is not available on this platform. This may cause the server to present an incorrect TLS certificate, which can cause validation failures. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#snimissingwarning.
#   SNIMissingWarning
# /home/loganwls/.local/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:120: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# ...

# %%
nyt
# Out:
# Columns:
# 	nyt_id	int
# 	byline	dict
# 	raw_headline	dict
# 	news_desk	str
# 	pub_date	datetime
# 	section_name	str
# 	web_url	str
# 	author	str
# 	headline	str
# 	body	str
# 	link_ids	list
# 	links	list
# 	paper_links	list
# 	DOI	list
# 	clean_body	str
# 	unigrams	dict
# 	filtered_unigrams	dict
# 	topic_id	int
#
# Rows: 1812
#
# Data:
# +--------+-------------------------------+-------------------------------+
# | nyt_id |             byline            |          raw_headline         |
# +--------+-------------------------------+-------------------------------+
# |   0    | {'person': [{'organization... | {'main': "'Fat Talk' Compe... |
# |   1    | {'person': [{'organization... | {'main': 'Really? The Clai... |
# |   2    | {'person': [{'firstname': ... | {'main': 'The New Rules fo... |
# |   3    | {'contributor': '', 'perso... | {'seo': 'Understanding Hoa... |
# |   4    | {'contributor': '', 'perso... | {'main': 'New Tools to Hun... |
# ...

# %%
nyt['DOI'].nnz()
# Out:
# 563

# %%
aca
# Out:
# Columns:
# 	DOI	str
# 	api_returned_doi	list
# 	author	list
# 	author_url	list
# 	issn	list
# 	publication_name	str
# 	publisher	str
# 	title	str
# 	pub_date	datetime
# 	eigenfactor	float
# 	open_access	int
#
# Rows: 1837
#
# Data:
# +----------------------------+------------------------------+
# |            DOI             |       api_returned_doi       |
# +----------------------------+------------------------------+
# |   10.1001/jama.2013.5892   |   [10.1001/jama.2013.5892]   |
# |    10.1056/nejmsa053935    |    [10.1056/nejmsa053935]    |
# | 10.1016/j.tics.2004.11.007 | [10.1016/j.tics.2004.11.007] |
# |     10.1002/oby.20384      |     [10.1002/oby.20384]      |
# |    10.1056/NEJMp1215606    |    [10.1056/nejmp1215606]    |
# |    10.1056/nejmsa042657    |    [10.1056/nejmsa042657]    |
# |   10.1161/01.cir.67.1.24   |   [10.1161/01.cir.67.1.24]   |
# |  10.1177/0363546511433279  |  [10.1177/0363546511433279]  |
# ...

# %%
len(aca.dropna('eigenfactor'))
# Out:
# 1189

# %%
# Number of DOIs found in NYT
len(nyt.stack('DOI','DOI')['DOI'].unique())
# Out:
# 1827
